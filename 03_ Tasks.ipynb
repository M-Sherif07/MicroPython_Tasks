# %% [markdown]
# # Week_03_ Tasks

# %% [markdown]
# ## Task-1 Light Switch System
# You are working as a junior embedded systems developer tasked with designing a basic LED control system for a small electronics workshop.
# The system allows the user to turn an LED on and off using two separate buttons:
#
# * **ON Button:** When pressed, it turns the LED ON.
#
# * **OFF Button:** When pressed, it turns the LED OFF.
#
# This design is similar to a light switch system, where one button acts as a dedicated ON switch and the other as a dedicated OFF switch.
#
#
# ### Hardware Requirements
# * Raspberry Pi Pico W
# * LED light
# * Two Buttons
# * Breadboard
# * Jumper wires

# %% [markdown]
# ## Task -2 Press and Hold Lamp
# You are working as an IoT trainee at a smart home company. The company wants to design a Press-and-Hold Lamp prototype using a Raspberry Pi Pico.
#
# The lamp should work as follows:
#
# * When the **button is pressed and held**, the LED (acting as the lamp) stays **ON**.
#
# * When the **button is released**, the LED turns **OFF** immediately.
#
# This simulates the real-world behaviour of a touch lamp or a safety control system, where holding down the switch provides power, and releasing it cuts the power.
#
# As part of your training, your supervisor requires you to:
#
# **1. Write clean and reusable code.**
#
# **2.** Use a **function** to control the LED instead of writing repeated if statements directly in the main loop.
#
#
# ### Hardware Requirements
# * Raspberry Pi Pico W
# * LED light
# * One Button
# * Breadboard
# * Jumper wires

# %% [markdown]
# ## Task -3  Blink Once on Demand
#
# You are part of a junior embedded systems training program. Your trainer has asked you to design a simple Blink Once on Demand system using a Raspberry Pi Pico.
#
# The requirements are:
#
# * The system has **one button**.
#
# * When the button is pressed, the LED will **blink once** (turn ON for **half a second**, then OFF).
#
# * If the button is pressed again, the LED blinks once again — **it does not stay ON continuously**.
#
# This project simulates real-world use cases, such as:
#
# * **A doorbell indicator light** that flashes once when pressed.
#
# * **A notification light** that blinks once when triggered.
#
# * **A one-time signal lamp** for acknowledgment in machinery.
#
# To encourage good coding practices, you must write a **function** to handle the blinking action. This avoids code repetition and makes the program easy to expand.
#
#
# ### Hardware Requirements
# * Raspberry Pi Pico W
# * LED light
# * One Button
# * Breadboard
# * Jumper wires

# %% [markdown]
# ## Task -4  Multi-Blink Confirmation
#
# You are tasked with building a confirmation signal system for a smart device prototype using a Raspberry Pi Pico.
#
# The system works like this:
#
# * A **button is pressed** to trigger the confirmation.
#
# * Instead of blinking once, the LED will blink **three times** in a row (short ON/OFF cycles) to act as a **confirmation signal**.
#
# * Each time the button is pressed, the LED repeats the **multi-blink pattern**.
#
# This behaviour is commonly used in the real world:
#
# * **Remote control pairing**: a light blinks multiple times to confirm pairing success.
#
# * **Security systems**: a lamp blinks to confirm an alarm has been armed/disarmed.
#
# * **IoT devices**: LEDs blink in a pattern to indicate a successful Wi-Fi connection.
#
# To practice structured coding, you are required to write the **multi-blink behaviour inside a function**. The main loop should only call the function when the button is pressed.
#
# ### Hardware Requirements
# * Raspberry Pi Pico W
# * LED light
# * One Button
# * Breadboard
# * Jumper wires

# %% [markdown]
# ## Task -5   Emergency Strobe (5 Rapid Flashes)
#
# You are working as a trainee in a **safety systems lab**. The supervisor assigns you to build an emergency **strobe light prototype** using a Raspberry Pi Pico.
#
# The system requirements:
#
# * A **button** triggers the emergency strobe.
#
# * When pressed, the LED flashes **rapidly 5 times in a row** (ON/OFF cycles).
#
# * The flashing should happen automatically once per button press — no need to hold the button.
#
# This simulates real-world uses:
#
# * 🚨 **Emergency vehicles** (warning strobe lights).
#
# * 🔔 **Alarm confirmation** (visual alert).
#
# * ⚡ **System fault indicator** (rapid blinking to grab attention).
#
# The supervisor requires the **LED blink logic** to be written inside a **function**, so the code is structured and reusable.
#
# ### Hardware Requirements
# * Raspberry Pi Pico W
# * LED light
# * One Button
# * Breadboard
# * Jumper wires

# %% [markdown]
# ## Task - 6 Two-Hand Safety Interlock
#
# You’re prototyping a **safety interlock** for a lab tool. To prevent accidental activation, the device should only trigger when **both buttons are pressed together** (like two-hand controls on industrial machines). If just one button is pressed, nothing happens.
#
# You are designing a secure activation system for a prototype IoT device.
# * The device should **only activate when both buttons are pressed at the same time**.
#
# * If **only one button** is pressed, nothing happens (the LED stays off).
#
# * When the correct combination (both buttons) is pressed, the LED provides a confirmation signal (e.g., blink sequence).
#
# This kind of **two-hand safety control** is widely used in:
#
# * **Industrial machines** (requiring two-hand activation for safety).
#
# * **Lock systems** (two-step or dual-user verification).
#
# * **IoT devices** (secure pairing, access control).
#
# ⚠️ You are required to handle the **LED confirmation** inside a **function** to enforce good coding practice.
#
# ### Hardware Requirements
# * Raspberry Pi Pico W
# * LED light
# * Two Button
# * Breadboard
# * Jumper wires
